# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('white')

# %%
stars_df = pd.read_csv("data/stars.csv")

# %%
g = sns.barplot(
    data=stars_df,
    y="name",
    x="aparent_magnitude"
)
g.set(
    xlim=(5,-5)
)
# Out:
# [(5.0, -5.0)]

# %%
g = sns.scatterplot(
    data=stars_df,
    x="distance",
    y="aparent_magnitude",
    size="magnitude"
)
